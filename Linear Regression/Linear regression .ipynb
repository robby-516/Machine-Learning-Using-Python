# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score


# Load the dataset
df = pd.read_csv("STUDENTSCORE_DATASET.csv")

x=df.iloc[:,:-1]
y=df.iloc[:,1]

# Scatter plot of the original data
plt.scatter(x, y, color='red')
plt.title('Student Scores vs Hours Studied')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.show()

# Splitting the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=40)

# Training the Linear Regression model
model = LinearRegression()
model.fit(x_train, y_train)

# Making predictions
y_pred = model.predict(x_test)

# Printing the actual and predicted values
print("Actual values:\n", y_test.values)
print("Predicted values:\n", y_pred)

# Plotting the regression line
plt.scatter(x,y, color='red', label='Original data')
plt.plot(x_test, y_pred, color='blue', linewidth=2, label='Predicted line')
plt.show()

# Predicting for a new value
# a=model.predict([[5.2]])
# print(a)
new_hours = pd.DataFrame([[5.2]], columns=['Hours'])  # Ensure new data
print(new_hoursmodel.predict(new_hours))



# Evaluating the model
print("\nMean Squared Error:", mean_squared_error(y_test, y_pred))
print("R^2 Score:", r2_score(y_test, y_pred))
# Out:
# Actual values:
#  [95 86 17 69 42 75 54 27 62]
# Predicted values:
#  [90.05323389 79.0394557  11.95553405 75.03444546 33.98309041 86.04822364
#  49.00187884 32.98183785 60.01565703]
# [53.00688909]
#
# Mean Squared Error: 42.8684601892673
# R^2 Score: 0.9297266802531642
